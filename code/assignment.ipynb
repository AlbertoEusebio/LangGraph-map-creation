# %%
from typing import Annotated, List, Tuple

from typing_extensions import TypedDict
import operator
from langchain.chat_models import init_chat_model
from langgraph.prebuilt import create_react_agent
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

planner_template = PromptTemplate.from_template(
    """You are a planning agent tasked with converting the user's objective into a sequence of detailed, logical steps.
        You specialize in the creation of conceptual maps for complex topics. Whenever a task is complex and requires multiple steps, subdivide it into smaller tasks.
        For example when the task involves the summarization of a large book, you may want to break it down into multiple steps.

        Example1: ["Describe relevant characters in the story", "list all chapters", "summarize chapters 1 - 10", "summarize chapters 11 - 20", "summarize chapters 21 - 37"]

        task: 
        {task_instruction}

        summary:
        {summary}

        Return a JSON array describing the ordered steps needed to complete the task. Each step should include:
        - step_id
        - description
        - expected_input
        - expected_output

        output: [{{json_array}}]
"""
)



replanner_template = PromptTemplate.from_template(
    """Your job is to check that the previously formulated plan is enought to properly solve the given task. Please make sure it is consistent and all the steps required by the user are covered by the current plan. Be meticoulous.
        
        plan:
        {plan}
        
        task: 
        {task_instruction}

        summary:
        {summary}

        Return a JSON array describing the ordered steps needed to complete the task. Each step should include:
        - step_id
        - description
        - expected_input
        - expected_output

        output: [{{json_array}}]
"""
)
summarizer_template = PromptTemplate.from_template(
    """You are an assistant tasked with summarizing input text for downstream use in a concept map generator.
        Summarize the key topics and structure in no more than 300 words, highlighting relationships or dependencies between concepts.
        Output the result in plain text. The summary should be long enough to answer precisely the question of the user.
            
        Always make sure that all available information relevant to the task is included. 
        When there are important entities, describe them and their role in the story.
        When there are chapters, summarize them in blocks (I-VII, VIII-XII, ... XXX - XXXVII and so on).

        user request:
        {task_instruction}

        context:
        {context}
""")


executor_template = PromptTemplate.from_template(
   """You are an executor agent. Your goal is to execute each step of the provided plan using the given summary of the input context.

    previous response:
    {response}

    plan step:
    {plan_step}

    summary:
    {summary}

    context:
    {context}

    return in output just the final user-facing response that comes from the execution of the plan. Be sure the expected output is consistent with the requirements of the plan step.
    The intermediate response should be formatted in Markdown format.
    
    response: {{response}}

""")

parser_template = PromptTemplate.from_template(
"""
    You are an expert parser who is going to produce a JSON structure encoding the final response provided by the reasoning part of the LLM into a conceptual map.

    instruction: {task_instruction}
    
    response: {response}
    
    output in JSON format as output of nested topics. If the instructions contain format requirements, try to implement them, but be sure not to modify the tree structure of the map: 
    - main_topic_keyword
        - subtopic_1_keyword
            - leaf_topic_keyword: "text description"
        - subtopic_2_keyword
            - leaf_topic_keyword: "text description"
"""
)

# %%
from langgraph.managed import RemainingSteps

class PlanExecute(TypedDict):
    context: str
    task_instruction: str
    summary: str
    plan: str
    plan_step: str
    messages: Annotated[List[str], add_messages]
    remaining_steps: RemainingSteps
    response: str

planner = create_react_agent(
    model = "openai:gpt-4.1",
    tools=[],
    name="map_planner",
    state_schema=PlanExecute,
    prompt=planner_template
)

replanner = create_react_agent(
    model = "openai:gpt-4.1",
    tools=[],
    name="map_replanner",
    state_schema=PlanExecute,
    prompt=planner_template
)

executor = create_react_agent(
    model = "openai:gpt-4.1",
    tools=[],
    name="map_writer",
    state_schema=PlanExecute,
    prompt=executor_template
)

summarizer = create_react_agent(
    model = "openai:gpt-4.1",
    tools=[],
    name="text_summarizer",
    state_schema=PlanExecute,
    prompt=summarizer_template
)

parser = create_react_agent(
    model = "openai:gpt-4.1",
    tools=[],
    name="map_producer",
    state_schema=PlanExecute,
    prompt=parser_template
)

# %%
import json
import re

def planning_node(state: PlanExecute):
    return {"plan": planner.invoke(state)['messages'][-1].content}

def replanning_node(state: PlanExecute):
    plan = state['plan']
    for i in range(3):
        plan = replanner.invoke(state)['messages'][-1].content
        state['plan'] = plan
    return {"plan": replanner.invoke(state)['messages'][-1].content}

def summary_node(state: PlanExecute):
    return {"summary": summarizer.invoke(state)['messages'][-1].content}

def executor_node(state: PlanExecute):

    plan = state['plan']
    plan = re.search(r'\[.*\]', plan, re.DOTALL).group(0)

    plan_dict = json.loads(plan)
    
    resp = ""

    for plan_step in plan_dict:
        state['plan_step'] = plan_step
        state['response'] = resp
        resp = executor.invoke(state)['messages'][-1].content

    return {"response": resp}

def parser_node(state: PlanExecute):
    return {"response": parser.invoke(state)['messages'][-1].content}

# %%
from IPython.display import Image, display

graph_builder = StateGraph(PlanExecute)

# The first argument is the unique node name
# The second argument is the function or object that will be called whenever
# the node is used.
graph_builder.add_node("summarizer", summary_node)
graph_builder.add_node("planner", planning_node)
graph_builder.add_node("replanner", replanning_node)
graph_builder.add_node("executor", executor_node)
graph_builder.add_node("parser", parser_node)

graph_builder.add_edge(START, "summarizer")
graph_builder.add_edge("summarizer", "planner")
graph_builder.add_edge("planner", "replanner")
graph_builder.add_edge("replanner", "executor")
graph_builder.add_edge("executor", 'parser')
graph_builder.add_edge("parser", END)

graph = graph_builder.compile()

# display(Image(graph.get_graph().draw_mermaid_png()))

# %%
file = open('./i_promessi_sposi.txt', 'r')
context = file.read()
file.close()
len(context)
# Out:
# 1318090

# %%
instruction = """Genera una mappa in inglese, tono divulgativo. Ogni sezione principale deve contenere il titolo e numero del capitolo nel fomato "Capitolo ZZZZ: titolo" e ogni sottosessione deve essere dedicata alla storia di un personaggio in quel capitolo più una sezione bonus con il riassunto breve del capitolo intitolata "summary". CREA UN NODO PER OGNI SINGOLO CAPITOLO"""

# %%
final_state = None

for event in graph.stream({"context": context, "task_instruction": instruction}):
    for value in event.values():
        print(value)
        final_state = value
# Out:
# {'summary': 'Below is the structured summary concept map instructions, in plain text, following your requirements. Each chapter is a node, with the format "Capitolo ZZZZ: titolo". For each, a bonus "summary" subsection highlights the chapter\'s events; additional subsections identify the main characters or their story in the chapter.\n\n---\n\nCapitolo I: The Beginning of the Story\n- Don Abbondio’s Encounter\n  - Don Abbondio, a timid village priest, is threatened by two “bravi” (thugs) to prevent the marriage of Renzo and Lucia.\n- Social Context\n  - Description of Lake Como region, local power structures, prepotence of nobles, and impotence of laws.\n- Summary\n  - Don Abbondio, fearful and passive, is blocked from officiating Renzo and Lucia’s wedding due to threats from Don Rodrigo’s men.\n\nCapitolo II: Renzo’s Disappointment\n- Renzo’s Story\n  - Renzo expects to get married but finds Don Abbondio evasive; Renzo confronts the priest but receives weak excuses.\n- Community Interactions\n  - Renzo seeks answers from Perpetua, Don Abbondio’s servant, a witness to the tension.\n- Summary\n  - Renzo suspects foul play in the cancelled wedding but cannot get a straight answer; Don Abbondio feigns illness to avoid involvement.\n\nCapitolo III: Lucia’s Dilemma\n- Lucia’s Story\n  - Lucia reveals to her mother, Agnese, and Renzo that Don Rodrigo desires her; she has sought advice from Father Cristoforo.\n- Seeking Legal Help\n  - Agnese sends Renzo to a lawyer, Azzecca-garbugli, who turns him away, fearing to contest Don Rodrigo’s power.\n- Summary\n  - The couple seeks help but faces rejection from authorities and realizes Don Rodrigo is behind their troubles.\n\nCapitolo IV: Father Cristoforo’s Past\n- Cristoforo’s Story\n  - The Backstory: Cristoforo was once Lodovico, a young noble who became a Capuchin friar after an act of violence, dedicating his life to defending the oppressed.\n- Setting\n  - The small village and the convent’s proximity to Don Rodrigo’s influence.\n- Summary\n  - Father Cristoforo emerges as an ally for Renzo & Lucia, a man of experience, penitence, and moral courage.\n\nCapitolo V: Father Cristoforo’s Intervention\n- Father Cristoforo at Agnese’s House\n  - Responds to Lucia\'s plight, vows to help, and decides to confront Don Rodrigo.\n- Renzo and Lucia’s Plan\n  - A desperate plan for a secret marriage is discussed.\n- Summary\n  - Father Cristoforo chooses a diplomatic approach; Renzo, Lucia, and Agnese look for alternative paths to get married.\n\nCapitolo VI: Confrontation with Don Rodrigo\n- Don Rodrigo’s Power\n  - Father Cristoforo confronts Don Rodrigo, who refuses to back down, exposing his abusive power.\n- Household Dynamics\n  - The role of Don Rodrigo’s servants and the complicity of the village.\n- Summary\n  - The attempt to reason with Don Rodrigo fails; father Cristoforo has a tense altercation.\n\nCapitolo VII: The Secret Marriage Attempt\n- Renzo & Allies’ Action\n  - The group (Renzo, Lucia, Agnese, Tonio, Gervaso) attempts a forced marriage in Don Abbondio’s home, relying on a loophole; Perpetua is distracted by Agnese.\n- Chaos\n  - The plan fails dramatically as Don Abbondio resists, causing a scene that summons villagers and authorities.\n- Summary\n  - The secret plan is uncovered, resulting in turmoil and the couple’s further endangerment.\n\nCapitolo VIII: Carneade? Who Was He?\n- Don Abbondio’s Perspective\n  - The chapter humorously shows Don Abbondio mulling over obscure scholarly references just before chaos strikes.\n- The Attempt Fails\n  - The detailed account of the failed marriage, Don Abbondio’s fear, and subsequent uproar in the village.\n- Summary\n  - The marriage attempt collapses, highlighting both comic and tragic elements in the characters’ struggles.\n\nCapitolo IX: The Flight\n- Escape from Danger\n  - With direct threats looming, Renzo, Lucia, and Agnese plan to flee their village, using connections at the Capuchin convent.\n- Help from the Friars\n  -  ...
# {'plan': '[\n  {\n    "step_id": 1,\n    "description": "Identify and list every single chapter of the book, with their official titles.",\n    "expected_input": "Full text of the book or a reliable chapter listing.",\n    "expected_output": "An ordered list of chapters, each with number and title, e.g., Capitolo I: The Beginning of the Story."\n  },\n  {\n    "step_id": 2,\n    "description": "For each chapter, identify the main characters whose personal stories or perspectives are most prominent in that chapter.",\n    "expected_input": "List of chapters; per-chapter synopses or full text.",\n    "expected_output": "For each chapter, a list of main characters or their storyline as it unfolds in that chapter."\n  },\n  {\n    "step_id": 3,\n    "description": "Write a short summary for each chapter, capturing the key events and developments, in a clear, divulgative English style.",\n    "expected_input": "Per-chapter content and context; previous lists.",\n    "expected_output": "For each chapter, a brief summary section titled \'summary\' highlighting the central events."\n  },\n  {\n    "step_id": 4,\n    "description": "Compose a section for each chapter that details the specific role or experience of each identified main character within that chapter.",\n    "expected_input": "Main characters per chapter; chapter content; previous notes.",\n    "expected_output": "For each chapter, one or more subsections dedicated to the main character(s), summarizing their experience, actions, or perspective."\n  },\n  {\n    "step_id": 5,\n    "description": "Combine, for each chapter node, the following: \'Capitolo ZZZZ: titolo\', a subsection for each main character, and a bonus \'summary\' subsection.",\n    "expected_input": "Lists and text outputs from Steps 1-4.",\n    "expected_output": "For every chapter, a structured node containing its title, character subsections, and a summary subsection."\n  },\n  {\n    "step_id": 6,\n    "description": "Ensure that every chapter—even those with little happening or where only minor characters appear—has its own node following the required format.",\n    "expected_input": "Complete chapter-by-chapter breakdown.",\n    "expected_output": "A comprehensive list of chapter nodes, one per chapter, each following the required structure."\n  },\n  {\n    "step_id": 7,\n    "description": "Review and organize all chapter nodes as an ordered conceptual map in plain text, maintaining clear, divulgative English and consistent formatting throughout.",\n    "expected_input": "All prepared nodes from Step 6.",\n    "expected_output": "A continuous, well-structured textual conceptual map matching the user’s requirements."\n  },\n  {\n    "step_id": 8,\n    "description": "Include a final relationships/dependencies section that outlines the major interconnections between characters, events, and themes throughout the conceptual map.",\n    "expected_input": "Global view of chapter nodes; understanding of story arcs.",\n    "expected_output": "A summary section describing overarching relationships, dependencies, and thematic links in the story."\n  }\n]'}
# {'plan': '[\n  {\n    "step_id": 1,\n    "description": "List all chapters and their titles in the format \'Capitolo ZZZZ: titolo\', ensuring every single chapter becomes a main conceptual node.",\n    "expected_input": "Full list of chapters and their English titles for the work to be mapped (e.g., \'I Promessi Sposi\').",\n    "expected_output": "Ordered list of chapters labeled as \'Capitolo ZZZZ: titolo\' to serve as primary map nodes."\n  },\n  {\n    "step_id": 2,\n    "description": "For each chapter, identify all key characters who play a significant role or whose story is advanced. Create a dedicated subsection for each within the node.",\n    "expected_input": "Detailed synopsis or text of each chapter.",\n    "expected_output": "For every chapter node, a list of subsections titled with the name of each relevant character, summarizing their involvement and development in that chapter."\n  },\n  {\n    "step_id": 3,\n    "description": "Within each chapter node, add a \'summary\' subsection which concisely recounts the principal events and developments of the chapter.",\n    "expected_input": "Analysis/summary of chapter content.",\n    "expected_output": "A short, clear summary paragraph for each chapter node, included as the bonus section titled \'summary.\'"\n  },\n  {\n    "step_id": 4,\n    "description": "Arrange chapter nodes in sequential order and structure the map so each node contains: the chapter’s title as the main heading, sub-nodes for each principal character’s story, and a summary node.",\n    "expected_input": "Outputs from previous steps for all chapters.",\n    "expected_output": "A concept map outline with 1 node per chapter, each including subsections for key characters and a \'summary.\'"\n  },\n  {\n    "step_id": 5,\n    "description": "Review and ensure tone is clear, divulgative (educational but accessible), and all elements are in English, respecting the user\'s language and conceptual mapping requirements.",\n    "expected_input": "Draft of the conceptual map from step 4.",\n    "expected_output": "Final concept map in plain text, ready for use by learners or readers, matching all requirements."\n  }\n]'}
# {'response': '# The Betrothed – Conceptual Map (Capitoli I–XXXVIII)\n\n---\n\n**Note**: This map follows the chapter-by-chapter sequence of Alessandro Manzoni’s _The Betrothed_ ("I Promessi Sposi"), summarizing each chapter’s key events and highlighting the main characters and themes. The tone is divulgative and clear, designed for learners and general readers. Relationships and overarching themes are recapped at the end. All elements are in English; Italian terms are included in parentheses where they clarify context.\n\n---\n\n### Capitolo I: The Beginning of the Story\n- **Don Abbondio’s Ordeal**\n  - Don Abbondio, a timid country priest, is threatened by Don Rodrigo’s thugs to prevent the marriage of Renzo and Lucia.\n- **Society**\n  - Snapshot of 17th century Lombardy: noble power, abuse, and ineffective legal system.\n- **Summary**\n  - Don Abbondio embodies the weakness of common folk against the arrogance of the powerful.\n\n### Capitolo II: Renzo’s Disappointment\n- **Main Characters**\n  - Renzo, Lucia’s fiancé, finds Don Abbondio evasive; Perpetua (the priest’s servant) hints at threats.\n- **Summary**\n  - Renzo experiences a web of silence, realizing the marriage’s cancellation is due to higher powers.\n\n### Capitolo III: Lucia’s Dilemma\n- **Main Characters**\n  - Lucia confides in her mother (Agnese) and Renzo about Don Rodrigo’s unwanted attention; legal aid fails them.\n- **Summary**\n  - Both church and civil authorities are helpless; Don Rodrigo’s menace becomes tangible.\n\n### Capitolo IV: Father Cristoforo’s Past\n- **Main Characters**\n  - Father Cristoforo’s backstory: once a nobleman, now a Capuchin friar and champion of the oppressed.\n- **Summary**\n  - He emerges as the protagonists’ moral protector, bringing hope.\n\n### Capitolo V: Father Cristoforo’s Intervention\n- **Events**\n  - Father Cristoforo pledges to help, confronting Don Rodrigo; a plan for a secret wedding arises.\n- **Summary**\n  - Tactics “from below” begin to oppose injustice.\n\n### Capitolo VI: Confrontation with Don Rodrigo\n- **Events**\n  - Father Cristoforo’s attempt at mediation is rebuffed; Don Rodrigo displays his brutal power.\n- **Summary**\n  - Religious authority clashes with secular power; the protagonists’ danger increases.\n\n### Capitolo VII: The Secret Marriage Attempt\n- **Events**\n  - Renzo, Lucia, and friends try to force Don Abbondio into a clandestine marriage; plan fails.\n- **Summary**\n  - The failed plot prompts escalation and chaos.\n\n### Capitolo VIII: Carneade? Who Was He?\n- **Perspective**\n  - Don Abbondio fumbles with academic distractions, misses the storm brewing around him.\n- **Summary**\n  - The failed marriage attempt highlights individual uncertainty versus social pressures.\n\n### Capitolo IX: The Flight\n- **Events**\n  - Renzo, Lucia, and Agnese flee with help from Father Cristoforo and the Capuchin friars.\n- **Summary**\n  - Their forced exile marks the beginning of the “diaspora of the innocent.”\n\n### Capitolo X: Lucia at Monza\n- **Main Characters**\n  - Lucia, Agnese, and the troubled Nun of Monza (Gertrude).\n- **Summary**\n  - Women’s solidarity meets the complex realities of convent life and female repression.\n\n### Capitolo XI: Renzo in Milan\n- **Events**\n  - Renzo becomes embroiled in Milan’s bread riots during a famine.\n- **Summary**\n  - Milan is pictured as a site of social chaos where the innocent are at risk.\n\n### Capitolo XII: The Riots in Milan\n- **Events**\n  - Riots spiral as crowds demand bread; mob justice takes centre stage.\n- **Summary**\n  - Highlights the dangers and volatility of collective anger in times of want.\n\n### Capitolo XIII: The Fall of the Provvisionato\n- **Events**\n  - Renzo is scapegoated by the mob; Ferrer’s political intervention saves an official.\n- **Summary**\n  - Exposes the fragile balance of power between mob and authority.\n\n### Capitolo XIV: Aftermath and Flight\n- **Events**\n  - Renzo, now a fugitive, escapes Milan’s b ...
# {'response': '{\n  "the_betrothed_concept_map": {\n    "Capitolo I: The Beginning of the Story": {\n      "Don Abbondio\'s Ordeal": "Don Abbondio, a timid country priest, is threatened by Don Rodrigo’s thugs to prevent the marriage of Renzo and Lucia.",\n      "Society": "Snapshot of 17th century Lombardy: noble power, abuse, and ineffective legal system.",\n      "summary": "Don Abbondio embodies the weakness of common folk against the arrogance of the powerful."\n    },\n    "Capitolo II: Renzo’s Disappointment": {\n      "Renzo and Perpetua": "Renzo, Lucia’s fiancé, finds Don Abbondio evasive; Perpetua (the priest’s servant) hints at threats.",\n      "summary": "Renzo experiences a web of silence, realizing the marriage’s cancellation is due to higher powers."\n    },\n    "Capitolo III: Lucia’s Dilemma": {\n      "Lucia and Agnese": "Lucia confides in her mother (Agnese) and Renzo about Don Rodrigo’s unwanted attention; legal aid fails them.",\n      "summary": "Both church and civil authorities are helpless; Don Rodrigo’s menace becomes tangible."\n    },\n    "Capitolo IV: Father Cristoforo’s Past": {\n      "Father Cristoforo’s Backstory": "Once a nobleman, now a Capuchin friar and champion of the oppressed.",\n      "summary": "He emerges as the protagonists’ moral protector, bringing hope."\n    },\n    "Capitolo V: Father Cristoforo’s Intervention": {\n      "Intervention": "Father Cristoforo pledges to help, confronting Don Rodrigo; a plan for a secret wedding arises.",\n      "summary": "Tactics “from below” begin to oppose injustice."\n    },\n    "Capitolo VI: Confrontation with Don Rodrigo": {\n      "Cristoforo and Rodrigo": "Father Cristoforo’s attempt at mediation is rebuffed; Don Rodrigo displays his brutal power.",\n      "summary": "Religious authority clashes with secular power; the protagonists’ danger increases."\n    },\n    "Capitolo VII: The Secret Marriage Attempt": {\n      "Renzo and Friends": "Renzo, Lucia, and friends try to force Don Abbondio into a clandestine marriage; plan fails.",\n      "summary": "The failed plot prompts escalation and chaos."\n    },\n    "Capitolo VIII: Carneade? Who Was He?": {\n      "Don Abbondio’s Perspective": "Don Abbondio fumbles with academic distractions, misses the storm brewing around him.",\n      "summary": "The failed marriage attempt highlights individual uncertainty versus social pressures."\n    },\n    "Capitolo IX: The Flight": {\n      "The Fugitives": "Renzo, Lucia, and Agnese flee with help from Father Cristoforo and the Capuchin friars.",\n      "summary": "Their forced exile marks the beginning of the “diaspora of the innocent.”"\n    },\n    "Capitolo X: Lucia at Monza": {\n      "Lucia and Gertrude": "Lucia, Agnese, and the troubled Nun of Monza (Gertrude) intersect.",\n      "summary": "Women’s solidarity meets the complex realities of convent life and female repression."\n    },\n    "Capitolo XI: Renzo in Milan": {\n      "Renzo in the City": "Renzo becomes embroiled in Milan’s bread riots during a famine.",\n      "summary": "Milan is pictured as a site of social chaos where the innocent are at risk."\n    },\n    "Capitolo XII: The Riots in Milan": {\n      "The Crowd": "Riots spiral as crowds demand bread; mob justice takes centre stage.",\n      "summary": "Highlights the dangers and volatility of collective anger in times of want."\n    },\n    "Capitolo XIII: The Fall of the Provvisionato": {\n      "Renzo Scapegoated": "Renzo is scapegoated by the mob; Ferrer’s political intervention saves an official.",\n      "summary": "Exposes the fragile balance of power between mob and authority."\n    },\n    "Capitolo XIV: Aftermath and Flight": {\n      "Renzo Escapes": "Renzo, now a fugitive, escapes Milan’s breakdown of social order.",\n      "summary": "Exile and wandering as responses to senseless injustice."\n    },\n    "Capitolo XV: Renzo’s Arrest": {\n      "Arrest and Escape": "Renzo is arrested but escapes thanks to public confusio ...

# %%
response = final_state['response']
response = re.search(r"{.*}", response, re.DOTALL).group(0)
concept_map = json.loads(response)

print(concept_map)
# Out:
# {'the_betrothed_concept_map': {'Capitolo I: The Beginning of the Story': {"Don Abbondio's Ordeal": 'Don Abbondio, a timid country priest, is threatened by Don Rodrigo’s thugs to prevent the marriage of Renzo and Lucia.', 'Society': 'Snapshot of 17th century Lombardy: noble power, abuse, and ineffective legal system.', 'summary': 'Don Abbondio embodies the weakness of common folk against the arrogance of the powerful.'}, 'Capitolo II: Renzo’s Disappointment': {'Renzo and Perpetua': 'Renzo, Lucia’s fiancé, finds Don Abbondio evasive; Perpetua (the priest’s servant) hints at threats.', 'summary': 'Renzo experiences a web of silence, realizing the marriage’s cancellation is due to higher powers.'}, 'Capitolo III: Lucia’s Dilemma': {'Lucia and Agnese': 'Lucia confides in her mother (Agnese) and Renzo about Don Rodrigo’s unwanted attention; legal aid fails them.', 'summary': 'Both church and civil authorities are helpless; Don Rodrigo’s menace becomes tangible.'}, 'Capitolo IV: Father Cristoforo’s Past': {'Father Cristoforo’s Backstory': 'Once a nobleman, now a Capuchin friar and champion of the oppressed.', 'summary': 'He emerges as the protagonists’ moral protector, bringing hope.'}, 'Capitolo V: Father Cristoforo’s Intervention': {'Intervention': 'Father Cristoforo pledges to help, confronting Don Rodrigo; a plan for a secret wedding arises.', 'summary': 'Tactics “from below” begin to oppose injustice.'}, 'Capitolo VI: Confrontation with Don Rodrigo': {'Cristoforo and Rodrigo': 'Father Cristoforo’s attempt at mediation is rebuffed; Don Rodrigo displays his brutal power.', 'summary': 'Religious authority clashes with secular power; the protagonists’ danger increases.'}, 'Capitolo VII: The Secret Marriage Attempt': {'Renzo and Friends': 'Renzo, Lucia, and friends try to force Don Abbondio into a clandestine marriage; plan fails.', 'summary': 'The failed plot prompts escalation and chaos.'}, 'Capitolo VIII: Carneade? Who Was He?': {'Don Abbondio’s Perspective': 'Don Abbondio fumbles with academic distractions, misses the storm brewing around him.', 'summary': 'The failed marriage attempt highlights individual uncertainty versus social pressures.'}, 'Capitolo IX: The Flight': {'The Fugitives': 'Renzo, Lucia, and Agnese flee with help from Father Cristoforo and the Capuchin friars.', 'summary': 'Their forced exile marks the beginning of the “diaspora of the innocent.”'}, 'Capitolo X: Lucia at Monza': {'Lucia and Gertrude': 'Lucia, Agnese, and the troubled Nun of Monza (Gertrude) intersect.', 'summary': 'Women’s solidarity meets the complex realities of convent life and female repression.'}, 'Capitolo XI: Renzo in Milan': {'Renzo in the City': 'Renzo becomes embroiled in Milan’s bread riots during a famine.', 'summary': 'Milan is pictured as a site of social chaos where the innocent are at risk.'}, 'Capitolo XII: The Riots in Milan': {'The Crowd': 'Riots spiral as crowds demand bread; mob justice takes centre stage.', 'summary': 'Highlights the dangers and volatility of collective anger in times of want.'}, 'Capitolo XIII: The Fall of the Provvisionato': {'Renzo Scapegoated': 'Renzo is scapegoated by the mob; Ferrer’s political intervention saves an official.', 'summary': 'Exposes the fragile balance of power between mob and authority.'}, 'Capitolo XIV: Aftermath and Flight': {'Renzo Escapes': 'Renzo, now a fugitive, escapes Milan’s breakdown of social order.', 'summary': 'Exile and wandering as responses to senseless injustice.'}, 'Capitolo XV: Renzo’s Arrest': {'Arrest and Escape': 'Renzo is arrested but escapes thanks to public confusion.', 'summary': 'The limits and absurdities of official justice.'}, 'Capitolo XVI: Toward Bergamo': {'Journey and Hardship': 'Renzo journeys through war- and famine-ravaged territory, seeking sanctuary in Bergamo.', 'summary': 'Exile becomes a journey of maturity and new hopes.'}, 'Capitolo XVII: The War and Its Impact': {'War’s Toll': 'The local toll and disruption caused by the War of Spanish Succes ...

# %%
# Generalized function to render any JSON tree with unlimited layers and fun styling
def render_json_tree_html(data, level=0):
    html = ""
    indent = "  " * level
    if isinstance(data, dict):
        for key, value in data.items():
            display_key = str(key).replace("_", " ").capitalize()
            emoji = "🧠" if level == 0 else "📂"
            html += f"{indent}<details open><summary>{emoji} <strong>{display_key}</strong> 🌟</summary>\n"
            html += render_json_tree_html(value, level + 1)
            html += f"{indent}</details>\n"
    elif isinstance(data, list):
        for i, item in enumerate(data):
            html += f"{indent}<details open><summary>📚 <strong>Item {i+1}</strong></summary>\n"
            html += render_json_tree_html(item, level + 1)
            html += f"{indent}</details>\n"
    else:
        html += f"{indent}<p class='text-blurb'>🔸 {str(data)}</p>\n"
    return html

# Wrap it in a magical HTML document
generic_html = f"""
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<title>🧩 Conceptual Map </title>
<style>
  @import url('https://fonts.googleapis.com/css2?family=Indie+Flower&family=Fredoka+One&display=swap');

  body {{
    font-family: 'Indie Flower', cursive;
    background: linear-gradient(to right, #fbc2eb, #a6c1ee);
    color: #2d2d2d;
    padding: 40px;
  }}
  h1 {{
    font-family: 'Fredoka One', cursive;
    font-size: 3em;
    text-align: center;
    color: #ff006e;
    margin-bottom: 30px;
  }}
  details {{
    background: #ffffffc9;
    border-radius: 10px;
    border: 2px dashed #ff70a6;
    padding: 12px;
    margin-bottom: 10px;
    box-shadow: 2px 2px 8px rgba(0,0,0,0.05);
  }}
  details:hover {{
    background-color: #fff0f6;
  }}
  summary {{
    font-size: 1.2em;
    color: #5c2a9d;
    cursor: pointer;
    font-weight: bold;
  }}
  .text-blurb {{
    margin: 8px 0 8px 20px;
    font-size: 1.05em;
    background: #fdfcdc;
    padding: 10px;
    border-left: 4px solid #ffd166;
    border-radius: 6px;
  }}
</style>
</head>
<body>
<h1>🧩 Conceptual Map </h1>
{render_json_tree_html(concept_map)}
<p style='text-align:center;'>🔍 This tree adapts to <strong>any</strong> JSON structure — deeply nested, irregular, or totally wild!</p>
</body>
</html>
"""

# Save to file
generic_html_path = "concept_map.html"
with open(generic_html_path, "w", encoding="utf-8") as f:
    f.write(generic_html)

generic_html_path
# Out:
# 'concept_map.html'
